# %% [markdown]
# ## CZ 7
# ### Exercise 7.2.a.b
# ![image info](images/7_2_a.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize
import math 

def f(x):
  return x**2+4*math.cos(x)

x = np.linspace(1,2,1000)

y = x**2+4*np.cos(x)
plt.plot(x, y)

minimum = optimize.golden(f, brack=(1,2), full_output=True)
minimum
# Out:
# (1.895494267277966, 2.316808419788213, 42)

# %% [markdown]
# ### Exercise 7.3
# ![image info](images/7_3.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize

def f(x):
  return 8*np.exp(1-x)+7*np.log(x)

x = np.linspace(1,2,1000)

plt.plot(x, f(x))

minimum = optimize.golden(f, brack=(1,2))
print(("Golden", minimum))

minimum = optimize.minimize
# Out:
# ('Golden', 1.6093810624542564)
# 1.6093810624542564

# %% [markdown]
# ### Exercise 7.10
# ![image info](images/7_10.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize

def g1(x):
  return (2*x-1)**2+4*(4-1024*x)**4

root = optimize.newton(g1, x0=0, full_output=True, disp=True)
root
# Out:
# (0.003909441884765515,
#        converged: True
#             flag: 'converged'
#   function_calls: 17
#       iterations: 16
#             root: 0.003909441884765515)
